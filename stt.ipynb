# %% [markdown]
# # What does your voice look like?

# %%
from dotenv import load_dotenv
import os
from openai import OpenAI

load_dotenv()

client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# %% [markdown]
# # Whisper API

# %%
from dotenv import load_dotenv
import os
from openai import OpenAI

load_dotenv()

client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

with open("audio/HI009clip.mp3", "rb") as audio_file:
    transcript = client.audio.transcriptions.create(
        model="gpt-4o-mini-transcribe",
        file=audio_file
    )

print(transcript.text)
# Out:
# Now, I hear that there's a Hawaiian custom of something called a hukilau. Hukilau, hukilau is that they have a rope, end of the rope they have a net there. They surround that certain place and they drag the net. They surround it, you mean they carry the net out? Carry the net, uh-huh. How do they, is there something to keep the net floating? Yeah, some have those floaters floating. Some they have laid down on the bottom and they drag that net in. What do the floats, what are the floats made of? The floats made of those coconut, dry coconut, I guess. Oh, dry coconuts, that's a good use for coconut. And that floats the top of the net. Top of the net. Now, the word lau means leaf, doesn't it? Lau, lau is the leaf. Alright, well now, the word does the leaf come in in this hukilau? Hukilau, the leaves, you know, this one at the top, top of the rope, so that when they pull, the fish is going to not jump over the rope. The ropes, the leaves keep the fish from jumping over? They scare them away. They scare them away, but they want to go down in the water, see. When some moment you go down in the water there, they will go to the net. They have a pocket on the net. They have a pocket on the net. Now, the bottom of the net then. Bottom of the net, they have a pocket. The bottom must have some kind of things to make it sink. Sink is a lead, they have a lead. Oh, they have lead on it, I see. Then somebody goes out and puts the net out around. Yeah, they throw it with the boat. With the boat. Two boats they go around, throw it all around. And then who pulls it in? Well, they have a lot of, from the shore, about 40, 50 guys there pull that rope up. Ah, I see. And they must have a pretty big school of fish there. Yeah, once in a while they have a nice school, right? And then they pull them all in and the fish don't, are scared to jump out, so they get caught. No, they all line up on the net already. They get caught in the net. I suppose the top of the net comes in sooner than the bottom, so they, if they do try to go out, they're in that pocket. Yeah, they have to take on about six or seven guys swimming on that around the net to watch in how the fish is going. Oh, I see. Then they chase them at the hole. Uh-huh. Well, about how much fish do they get out of a good haul of those? Once I saw up Waimea, they caught about, about a ton, I guess, in those akule. Oh, they have a nice crew up there. What's akule? The akule, some kind of, you know, the, how you used to call akule, akule. Japanese call it the ajito.

# %%
with open("audio/HI009clip.mp3", "rb") as audio_file:
    guided_transcript = client.audio.transcriptions.create(
        model="gpt-4o-mini-transcribe",
        file=audio_file,
        prompt="""
        This audio contains a discussion about Hawaiian culture.
        The conversation may include the words:
        hukilau,
        Hawaii,
        fishing,
        traditions,
        ocean,
        community.
        """
    )

print(guided_transcript.text)
# Out:
# I hear that there's a Hawaiian custom of something called a hukilau. Hukilau. Hukilau is that they have a rope. End of the rope, they have a net. They surround that certain place and they drag the net. They surround it, you mean they carry the net out? Carry the net, uh-huh. How do they, is there something to keep the net floating? Yeah, some have those floaters floating. Some have a lead on the bottom, then they drag that net in. What do the floats, what are the floats made of? The floats made of those coconut, dry coconut, I guess. Oh, dry coconuts. That's a good source for coconut. And that floats the top of the net. Top of the net. Now, the word lau means leaf, doesn't it? Lau, Lau is a leaf. All right, well now, the word does the leaf come in in this hukilau? Hukilau, the leaves, you know, they stay one at the top, top of the rope, so that when they pull, the fish is gonna not jump over the rope. The ropes, the leaves keep the fish from jumping over? They scare them away. They scare them away, so they want to go running in the water. So when some moments you go running in the water there, they will go to the net. They have a pocket on the net. They have a pocket on the net. Now, at the bottom of the net, then? Bottom of the net, they have a pocket. The bottom must have some kind of things to make it sink. Sink is a lead, they have a lead. Oh, they have lead on there, I see. Then somebody goes out and puts the net out around. Yeah, they do it with a boat. With a boat. Two boats, they go out. They go all around. And then who pulls it in? Well, they have a lot of, from the shore, about 40, 50 guys pull that rope out. Ah, I see. And they must have a pretty big school of fish there. Yeah, once in a while they have a nice school, right? And then they pull them all in and the fish are scared to jump out, so they get caught. No, they all line up on the net already. They get caught in the net. I suppose the top of the net comes in sooner than the bottom, so if they do try to go out, they're in that pocket. Yeah, they have the big one, you know, about six or seven guys swimming on that around the net to watch how the fish is going. Oh, I see. Then they chase it at the hole. Uh-huh. Well, about how much fish do they get out of a good haul of those? Once I saw up Waimea, they caught about a ton, I guess, of those akule. Oh, they have a nice crew up there. What's akule? Akule, some kind of, you know, how we used to call akule. Japanese called it aji.

# %%
with open("audio/HI009clip.mp3", "rb") as audio_file:
    unguided_transcript = client.audio.transcriptions.create(
        model="gpt-4o-mini-transcribe",
        file=audio_file
    )

print(unguided_transcript.text)
# Out:
# I hear that there's a Hawaiian custom of something called a hukilau. Hukilau, Hukilau is that they have a rope, end of the rope they have a net in there. They surround at a certain place and they drag the net. They surround it, you mean they carry the net out? Carry the net, uh-huh. How do they, is there something to keep the net floating? Well, some have those floaters floating. Some have a lay down on the bottom, then they drag the net in. What do the floats, what are the floats made of? The floats made of those, some coconut, dry coconut, I guess. Oh, dry coconut. That's a good use for coconut. And that floats the top of the net. Top of the net. Now, the word lau means leaf, doesn't it? Lau, lau is a leaf. All right, now, the, the word is the leaf come in in this hukilau. Hukilau, the leaves, you know, this one at the top, top of the rope. So that when they pull, the fish is gonna not jump over the rope. The ropes, the leaves keep the fish from jumping over, they scare them away? They scare them away, so they want to go underneath the water, see. Once the moment you go underneath the water there, they will go through the net. They have a pocket on the net. They have a pocket on the net. Now, the bottom of the net then. Bottom of the net, they have a pocket. The bottom must have some kind of things to make it sink. Sink is a leaf, they have a leaf. Oh, they have that on it, I see. Then somebody goes out and puts the net out around. Yeah, they throw with the boat. With the boat. With the two boats they go around, throw it all around. And then who pulls it in? Well, they have a lot of, from the shores, about 40-50 guys pull that rope up. Ah, I see. And they must have a pretty big school of fish there. Yeah, once in a while they have a nice school, right? And then they pull them all in and the fish don't, are scared to jump out, so they get caught. No, they all line up on the net already. They get caught in the net. I suppose the top of the net comes in sooner than the bottom, so they, if they do try to go out, they're in that pocket. Yeah, they have to take on, you know, about six or seven guys swimming on it around the net to watch in how the fish is going. Oh, I see. Then they're chasing at the hole. Well, about how much fish do they get out of a good haul of those? Once I saw up Waimea, they caught about, about a ton, I guess, of those aku. Oh, they have a nice crew up there. What's aku? Um, aku, some kind of, you know, the Hawaii used to call aku aku. Japanese called it aji.

# %%
print("GUIDED")
print(guided_transcript.text)

print("\n" + "="*60 + "\n")

print("UNGUIDED")
print(unguided_transcript.text)
# Out:
# GUIDED
# I hear that there's a Hawaiian custom of something called a hukilau. Hukilau. Hukilau is that they have a rope. End of the rope, they have a net. They surround that certain place and they drag the net. They surround it, you mean they carry the net out? Carry the net, uh-huh. How do they, is there something to keep the net floating? Yeah, some have those floaters floating. Some have a lead on the bottom, then they drag that net in. What do the floats, what are the floats made of? The floats made of those coconut, dry coconut, I guess. Oh, dry coconuts. That's a good source for coconut. And that floats the top of the net. Top of the net. Now, the word lau means leaf, doesn't it? Lau, Lau is a leaf. All right, well now, the word does the leaf come in in this hukilau? Hukilau, the leaves, you know, they stay one at the top, top of the rope, so that when they pull, the fish is gonna not jump over the rope. The ropes, the leaves keep the fish from jumping over? They scare them away. They scare them away, so they want to go running in the water. So when some moments you go running in the water there, they will go to the net. They have a pocket on the net. They have a pocket on the net. Now, at the bottom of the net, then? Bottom of the net, they have a pocket. The bottom must have some kind of things to make it sink. Sink is a lead, they have a lead. Oh, they have lead on there, I see. Then somebody goes out and puts the net out around. Yeah, they do it with a boat. With a boat. Two boats, they go out. They go all around. And then who pulls it in? Well, they have a lot of, from the shore, about 40, 50 guys pull that rope out. Ah, I see. And they must have a pretty big school of fish there. Yeah, once in a while they have a nice school, right? And then they pull them all in and the fish are scared to jump out, so they get caught. No, they all line up on the net already. They get caught in the net. I suppose the top of the net comes in sooner than the bottom, so if they do try to go out, they're in that pocket. Yeah, they have the big one, you know, about six or seven guys swimming on that around the net to watch how the fish is going. Oh, I see. Then they chase it at the hole. Uh-huh. Well, about how much fish do they get out of a good haul of those? Once I saw up Waimea, they caught about a ton, I guess, of those akule. Oh, they have a nice crew up there. What's akule? Akule, some kind of, you know, how we used to call akule. Japanese called it aji.
#
# ============================================================
#
# UNGUIDED
# I hear that there's a Hawaiian custom of something called a hukilau. Hukilau, Hukilau is that they have a rope, end of the rope they have a net in there. They surround at a certain place and they drag the net. They surround it, you mean they carry the net out? Carry the net, uh-huh. How do they, is there something to keep the net floating? Well, some have those floaters floating. Some have a lay down on the bottom, then they drag the net in. What do the floats, what are the floats made of? The floats made of those, some coconut, dry coconut, I guess. Oh, dry coconut. That's a good use for coconut. And that floats the top of the net. Top of the net. Now, the word lau means leaf, doesn't it? Lau, lau is a leaf. All right, now, the, the word is the leaf come in in this hukilau. Hukilau, the leaves, you know, this one at the top, top of the rope. So that when they pull, the fish is gonna not jump over the rope. The ropes, the leaves keep the fish from jumping over, they scare them away? They scare them away, so they want to go underneath the water, see. Once the moment you go underneath the water there, they will go through the net. They have a pocket on the net. They have a pocket on the net. Now, the bottom of the net then. Bottom of the net, they have a pocket. The bottom must have some kind of things to make it sink. Sink is a leaf, they have a leaf. Oh, they have that on it, I see. Then somebody goes out and puts the net out around. Yeah, they throw with the boat. With the boat. With the two boats they go around, throw it all around. And then who pulls it in? Well, they have a lot of, from the shores, about 40-50 guys pull that rope up. Ah, I see. And they must have a pretty big school of fish there. Yeah, once in a while they have a nice school, right? And then they pull them all in and the fish don't, are scared to jump out, so they get caught. No, they all line up on the net already. They get caught in the net. I suppose the top of the net comes in sooner than the bottom, so they, if they do try to go out, they're in that pocket. Yeah, they have to take on, you know, about six or seven guys swimming on it around the net to watch in how the fish is going. Oh, I see. Then they're chasing at the hole. Well, about how much fish do they get out of a good haul of those? Once I saw up Waimea, they caught about, about a ton, I guess, of those aku. Oh, they have a nice crew up there. What's aku? Um, aku, some kind of, you know, the Hawaii used to call aku aku. Japanese called it aji.

# %%
from pydub import AudioSegment
import os

audio = AudioSegment.from_mp3("audio/HI009clip.mp3")

chunk_length = 10 * 60 * 1000  # 10 minutes in milliseconds

os.makedirs("chunks", exist_ok=True)

for i in range(0, len(audio), chunk_length):
    chunk = audio[i:i + chunk_length]
    chunk.export(f"chunks/chunk_{i//chunk_length}.mp3", format="mp3")

print("Chunks created successfully!")
# Out:
# Chunks created successfully!

# %%
# Out:
# Finished transcribing all chunks!

# %%
for chunk in all_transcripts:
    print("=" * 60)
    print(chunk["chunk"])
    print(chunk["text"])
# Out:
# ============================================================
# chunk_0.mp3
# I hear that there's a Hawaiian custom of something called a hukilau. Hukilau. Hukilau is that they have a rope, and on the rope they have a net in it. They surround at a certain place, and they drag the net. They surround it, you mean they carry the net out? Carry the net, uh-huh. How do they, is there something to keep the net floating? Yeah, some have those floaters floating, some have a ladder on the bottom, then they drag the net in. What do the floats, what are the floats made of? The floats are made of those, some coconut, dry coconut, I guess. Oh, dry coconut. That's a good use for coconut. And that floats the top of the net. Top of the net. Now, the word lau means leaf, doesn't it? Lau, lau is a leaf. All right, well now, the word does the leaf come in in this hukilau? Hukilau, the leafs, you know, they take one at the top, top of the rope, so that when they pull, the fish will not jump over the rope. The ropes, the leaves keep the fish from jumping over? They scare them away. They scare the fish away. When they want to go down in the water, see. When some moments go down in the water there, they will go to the net. They have a pocket on the net. They have a pocket on the net. At the bottom of the net, then, Bottom of the net, they have a pocket. The water must have some kind of things to make it sink. Sink, it's a lead, they have a lead. Oh, they have lead on it, I see. Then, somebody goes out and puts the net out around. Yeah, they do it with a boat. With a boat. With two boats, they go out, towards all around. And then, who pulls it in? Well, they have a lot of, on the shore, about 40 or 50 guys there, pull that rope up. Ah, I see. And they must have a pretty big school of fish there. Yeah, most of them, they have a nice school, right? And then, they pull them all in, and the fish don't, are scared to jump out, so they get caught. No, they all line up on the net already. They get caught in the net. I suppose the top of the net comes in sooner than the bottom, so they, if they do try to go out there, that pocket. Yeah, they have to take on, you know, about six or seven guys swimming on it, around the net, to watching how the fish going. Oh, I see. Then they're chasing at the hole. Uh-huh. Well, about how much fish do they get out of a good haul of those? Once I saw a white net, they caught about, about a ton, I guess, of those akule. Oh, they have a nice crew up there. What's akule? The akule, some kind of, you know, the Hawaiians used to call akule akule. Japanese call it aji.

# %%
with open("transcript.txt", "w", encoding="utf-8") as file:
    for chunk in all_transcripts:
        file.write(chunk["chunk"] + "\n")
        file.write(chunk["text"] + "\n\n")

print("Transcript saved as transcript.txt")
# Out:
# Transcript saved as transcript.txt

# %%
import json

with open("transcript.json", "w", encoding="utf-8") as file:
    json.dump(all_transcripts, file, indent=4, ensure_ascii=False)

print("Transcript saved as transcript.json")
# Out:
# Transcript saved as transcript.json

# %%
def format_time(seconds):
    hours = int(seconds // 3600)
    minutes = int((seconds % 3600) // 60)
    secs = int(seconds % 60)
    milliseconds = int((seconds - int(seconds)) * 1000)

    return f"{hours:02}:{minutes:02}:{secs:02},{milliseconds:03}"


with open("transcript.srt", "w", encoding="utf-8") as f:

    current_time = 0

    for i, chunk in enumerate(all_transcripts, start=1):

        start = current_time
        end = current_time + 10

        f.write(f"{i}\n")
        f.write(f"{format_time(start)} --> {format_time(end)}\n")
        f.write(chunk["text"] + "\n\n")

        current_time += 10

print("Transcript saved as transcript.srt")
# Out:
# Transcript saved as transcript.srt

# %%
import scipy.io.wavfile as wavfile
from openai import OpenAI
import io
import os
from IPython.display import Audio, display
from dotenv import load_dotenv

load_dotenv()

client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

duration = 5  # seconds
sample_rate = 16000

print(f"🎤 Recording for {duration} seconds... Speak now!")
audio = sd.rec(int(duration * sample_rate), 
               samplerate=sample_rate, 
               channels=1, 
               dtype='float32')
sd.wait()
audio = audio.flatten()
print("✅ Recording complete!")


audio_int16 = np.int16(audio * 32767)

# Create in-memory WAV file
buffer = io.BytesIO()
wavfile.write(buffer, sample_rate, audio_int16)
buffer.seek(0)
buffer.name = "recording.wav"  # Whisper needs a filename

# Transcribe with Whisper
print("🤖 Transcribing with Whisper...")
transcript = client.audio.transcriptions.create(
    model="whisper-1",
    file=buffer
)

print("\n📝 Transcription:")
print("-" * 40)
print(transcript.text)

# %% [markdown]
# # Super Power: Context

# %%
import sounddevice as sd
import numpy as np
import scipy.io.wavfile as wavfile
from openai import OpenAI
import io
from IPython.display import Audio, display, Markdown

#client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# Display a 30-second reading text
reading_text = """
**Read this text aloud (about 30 seconds):**

The researchers' analyses of the wind farm data showed variable wind patterns. The project 
lead will lead the team through complex permit processes. They must present the present 
findings to investors. The 3 million contract includes clauses for force majeure 
events. Dr. García-Smith's team discovered that the enzyme's pH of 7.2 was optimal. The 
AI learned to differentiate between "read" (present) and "read" (past), processing live 
feeds versus archived content. The baroque bass player stood close to the entrance, too 
close to record properly.
"""

display(Markdown(reading_text))

# Record for 30 seconds
duration = 45
sample_rate = 16000

print(f"\n🎤 Recording for {duration} seconds... Start reading now!")
audio = sd.rec(int(duration * sample_rate), samplerate=sample_rate, channels=1, dtype='float32')
sd.wait()
audio = audio.flatten()
print("✅ Recording complete!")

display(Audio(audio, rate=sample_rate))


# Prepare audio
audio_int16 = np.int16(audio * 32767)
buffer = io.BytesIO()
wavfile.write(buffer, sample_rate, audio_int16)
buffer.seek(0)
buffer.name = "recording.wav"

# Transcribe without context prompt
print("🤖 Transcribing without context...")
transcript = client.audio.transcriptions.create(
    model="whisper-1",
    file=buffer,
)

print("\n📝 Transcription:")
print("-" * 40)
print(transcript.text)

# %%
# Transcribe with context prompt
print("🤖 Transcribing with context...")
transcript = client.audio.transcriptions.create(
    model="whisper-1",
    file=buffer,
    prompt = "heteronyms, homographs, lead metal, wind turbine, present tense, past tense read, pH levels, enzyme, García-Smith, force majeure, baroque, bass instrument, differentiate")

print("\n📝 Transcription:")
print("-" * 40)
print(transcript.text)

# %% [markdown]
# # Chunking

# %%
import sounddevice as sd
import numpy as np
import scipy.io.wavfile as wavfile
from openai import OpenAI
import io

#client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# Record longer audio
duration = 15  # seconds total
sample_rate = 16000
chunk_duration = 5  # seconds per chunk

print(f"🎤 Recording for {duration} seconds... Speak continuously!")
audio = sd.rec(int(duration * sample_rate), samplerate=sample_rate, channels=1, dtype='float32')
sd.wait()
audio = audio.flatten()
print("✅ Recording complete!")

display(Audio(audio, rate=sample_rate))


# Split audio into chunks
chunk_size = chunk_duration * sample_rate
chunks = [audio[i:i+chunk_size] for i in range(0, len(audio), chunk_size)]

print(f"\n🔪 Split into {len(chunks)} chunks")

# Transcribe each chunk
all_transcripts = []

for i, chunk in enumerate(chunks):
    print(f"\n🤖 Transcribing chunk {i+1}/{len(chunks)}...")
    
    # Prepare chunk buffer
    chunk_int16 = np.int16(chunk * 32767)
    buffer = io.BytesIO()
    wavfile.write(buffer, sample_rate, chunk_int16)
    buffer.seek(0)
    buffer.name = f"chunk_{i}.wav"
    
    # Transcribe
    transcript = client.audio.transcriptions.create(
        model="whisper-1",
        file=buffer
    )
    
    all_transcripts.append(transcript.text)
    print(f"Chunk {i+1}: {transcript.text}")

# Combine all transcripts
print("\n📝 Complete Transcription:")
print("-" * 40)
full_text = " ".join(all_transcripts)
print(full_text)

# %% [markdown]
# # Time Stamps

# %%
import sounddevice as sd
import numpy as np
import scipy.io.wavfile as wavfile
from openai import OpenAI
import io
from IPython.display import Audio, display

#client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

duration = 10  # seconds
sample_rate = 16000

print(f"🎤 Recording for {duration} seconds... Speak with pauses!")
audio = sd.rec(int(duration * sample_rate), samplerate=sample_rate, channels=1, dtype='float32')
sd.wait()
audio = audio.flatten()
print("✅ Recording complete!")

# Play back
display(Audio(audio, rate=sample_rate))

# Prepare audio
audio_int16 = np.int16(audio * 32767)
buffer = io.BytesIO()
wavfile.write(buffer, sample_rate, audio_int16)
buffer.seek(0)
buffer.name = "recording.wav"

# Get detailed transcription with timestamps
print("\n🤖 Transcribing with timestamps...")
transcript = client.audio.transcriptions.create(
    model="whisper-1",
    file=buffer,
    response_format="verbose_json",
    timestamp_granularities=["segment", "word"]  # Get both segment and word timestamps
)

# Display formatted timestamps
print("\n📝 Transcription with timestamps:")
print("-" * 40)

# Show segments with timestamps
if hasattr(transcript, 'segments'):
    for segment in transcript.segments:
        start = segment.start
        end = segment.end
        text = segment.text
        print(f"\n[{start:.2f}s - {end:.2f}s]")
        print(f"  {text}")

# Show word-level timestamps if available
if hasattr(transcript, 'words'):
    print("\n🔤 Word-level timing:")
    print("-" * 40)
    for word in transcript.words:
        word_text = word.word
        start = word.start
        end = word.end
        print(f"{word_text:15} [{start:.2f}s - {end:.2f}s]")

# Full text and metadata
print("\n📄 Full text:")
print(transcript.text)

print(f"\n🌍 Language detected: {transcript.language}")
print(f"⏱️ Total duration: {transcript.duration:.2f}s")
